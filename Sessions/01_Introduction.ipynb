# %% [markdown]
# # Introduction to Python #

# %% [markdown]
# ## Why Python ##

# %% [markdown]
# A comparison of the [popularity of programming](http://www.drewconway.com/zia/?p=2892) languages by [Drew Conway](http://www.drewconway.com/zia/?page_id=2).

# %%
from IPython.core.display import Image

# %%
Image("http://www.drewconway.com/zia/wp-content/uploads/2012/10/ranks_slope-400x300.png")

# %% [markdown]
# [larger version](http://www.drewconway.com/zia/wp-content/uploads/2012/10/ranks_slope.png)

# %%
Image("http://www.drewconway.com/zia/wp-content/uploads/2012/10/tier_members-300x224.png")

# %% [markdown]
# [larger version](http://www.drewconway.com/zia/wp-content/uploads/2012/10/tier_members.png)

# %% [markdown]
# ## Useful Python Packages
#
# * `pickle`
# * `collections`
# * `bisect`
#
# Many more packages exist, refer to the [complete list](http://docs.python.org/py-modindex.html) of packages in the standard library.

# %% [markdown]
# ## Scientific Python ##
#
# * `numpy`
# * `scipy`
# * `matplotlib`
